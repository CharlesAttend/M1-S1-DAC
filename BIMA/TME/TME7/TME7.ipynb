# %% [markdown]
# # Practical work 8: Split and Merge
#
# In this practical work, we implement and test the split and merge algorithm.

# %%
### Usefull libraries
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from icecream import ic

### Data
img_test = np.full((64,64),150,dtype=np.uint8)
img_test[32:48,16:16+32] = 100
img_test[8:24,40:56] = 50
angio = np.array(Image.open('img/angiogra.png'))
cam = np.array(Image.open('img/cameraman.png'))
muscle = np.array(Image.open('img/muscle.png'))
prisme = np.array(Image.open('img/prisme.png'))
seiche = np.array(Image.open('img/seiche.png'))

### Usefull functions
def neighbors(b,K):
    """ blockStat*list[blockStat]->list[blockStat]
        returns the list of neighbors of b and elements of K 
    """
    def belongsTo(x,y,a):
        """ int*int*BlockStat -> bool 
            Test if pixel (x,y) belongs to block a 
        """
        return x>=a[0] and y>=a[1] and x<a[0]+a[2] and y<a[1]+a[3]
    def areNeighbors(a,b):
        """ BlockStat**2 -> bool
            Test if a and b are neighbors
        """
        if a[2]>b[2] and a[3]>b[3]:
            a,b=b,a
        x,y = a[0]+a[2]//2,a[1]+a[3]//2
        return belongsTo(x+a[2],y,b) or belongsTo(x-a[2],y,b) or belongsTo(x,y+a[3],b) or belongsTo(x,y-a[3],b)
    N = []
    for n in K:
        if areNeighbors(b,n):
            N.append(n)
    return N
plt.imshow(img_test)

# %% [markdown]
# ## Exercise 1
#
# ### Question 1
# Write the recursive function ``split()`` discussed in tutorial work.
# It takes as input the image, a region, a predicate, and a variable number of arguments.
# The region is a Python formal type ``Block`` defined by:
# ```python
# type Block = tuple[int**4]
# ```
# The function ``split()`` returns a quadtree, a Python formal type, recursivelly defined by:
# ```python
# type QuadTree = list[(QuadTree**4|Block)]
# ```
#
# The predicate is a Python function with the following signature:
# ```python
# Array*Block*...->bool
# ```
# It can take a variable number of parameters which correspond to the parameters required by the predicate.

# %%
# type Block = tuple[int**4]
# type QuadTree = list[(QuadTree**4|Block)] 

def split(I,reg,pred,*args):
    """ Array*Block*(Array*Block*...->bool)*... -> 4-aire
        Performs a quadtree splitting of image I drived by a predicate
    """
    x, y, n, m = reg
    if pred(I, reg, *args) and n > 2 and m > 2:
        splited_n = n//2
        splited_m = m//2
        new_size = (splited_n, splited_m)
        return [
            split(I, (x             , y              , *new_size), pred, *args), # Nord Ouest
            split(I, (x             , y + splited_m  , *new_size), pred, *args), # Nord Est
            split(I, (x + splited_n , y              , *new_size), pred, *args), # Sud Ouest
            split(I, (x + splited_n , y + splited_m  , *new_size), pred, *args), # Sud Est
        ]
    else:
        return [reg]

# %% [markdown]
# ### Question 2
# Write the function ```predsplit(I,B,*args)``` with signature:
# ```python
# Array*Block*... -> bool
# ```
# that returns True if the standard deviation of image ``I`` computed in region ``B`` is greater than the first value of argument ``*args`` (it can be accessed simply by ``*args[0]``).

# %%
def predsplit(I,reg,*args):
    """ Array*Block*... -> bool
    """
    x,y,n,m = reg
    if np.std(I[x:x+n, y:y+m]) > args[0] :
        return True 
    else:
        return False

# %% [markdown]
# ### Question 3
# Write the function ``listRegions()`` which applies a depth-first search on the quadtree given as parameter, and returns the list of the leaves of the quadtree.
#
# Some recalls about lists in Python;
#  - Initialization: `L = []` (empty list)
#  - Add a element `a` into a list `L`: `L.append(a)`

# %%
def listRegions(L, blocks_list):
    """ QuadTree -> list[Block]
    """
    if isinstance(L, tuple): # C'est une feuille 
        blocks_list.append(L)
        return blocks_list
    else:
        for qt in L:
            listRegions(qt, blocks_list)
        return blocks_list

# %% [markdown]
# ### Question 4
# Test your codes on the synthetic image ``img_test`` seen in tutorial work. Print the value returned by ``split()`` as well as the one returned by ``listRegions()``.

# %%
L = split(img_test, (0,0, *img_test.shape), predsplit, 0)
L
# Out:
# [[(0, 0, 32, 32)],
#  [[[(0, 32, 8, 8)], [(0, 40, 8, 8)], [(8, 32, 8, 8)], [(8, 40, 8, 8)]],
#   [[(0, 48, 8, 8)], [(0, 56, 8, 8)], [(8, 48, 8, 8)], [(8, 56, 8, 8)]],
#   [[(16, 32, 8, 8)], [(16, 40, 8, 8)], [(24, 32, 8, 8)], [(24, 40, 8, 8)]],
#   [[(16, 48, 8, 8)], [(16, 56, 8, 8)], [(24, 48, 8, 8)], [(24, 56, 8, 8)]]],
#  [[(32, 0, 16, 16)],
#   [(32, 16, 16, 16)],
#   [(48, 0, 16, 16)],
#   [(48, 16, 16, 16)]],
#  [[(32, 32, 16, 16)],
#   [(32, 48, 16, 16)],
#   [(48, 32, 16, 16)],
#   [(48, 48, 16, 16)]]]

# %%
regions = listRegions(L, [])
print(regions)
len(regions)
# Out:
# [(0, 0, 32, 32), (0, 32, 8, 8), (0, 40, 8, 8), (8, 32, 8, 8), (8, 40, 8, 8), (0, 48, 8, 8), (0, 56, 8, 8), (8, 48, 8, 8), (8, 56, 8, 8), (16, 32, 8, 8), (16, 40, 8, 8), (24, 32, 8, 8), (24, 40, 8, 8), (16, 48, 8, 8), (16, 56, 8, 8), (24, 48, 8, 8), (24, 56, 8, 8), (32, 0, 16, 16), (32, 16, 16, 16), (48, 0, 16, 16), (48, 16, 16, 16), (32, 32, 16, 16), (32, 48, 16, 16), (48, 32, 16, 16), (48, 48, 16, 16)]
# 25

# %% [markdown]
# ### Question 5
# Write the function ```drawRegions(L,I)``` which takes as arguments a list of regions, an image, and returns an image  where the boundaries of each region have been traced with red color. Indication: the returned image is a hypermatrix of dimension 3, the third dimension is of size 3 and encodes the red, green and blue components of a RGB colorspace. Test the function on the previous example.

# %%
def drawRegions(LL,I):
    """ list[Block]*Array -> Array
        parcours de la liste dessin des régions 
    """
    new_I = np.dstack((I,I,I))
    red = np.array([255, 0, 0])
    for x, y, n, m in LL:
        new_I[x, y:y+m, :] = red # Axe des j sur m pixel
        new_I[x:x+n, y, :] = red # Axe des x sur n pixel
        
        if x + n == new_I.shape[0]:
            new_I[x+n-1, y:y+m, :] = red
        if y + m == new_I.shape[0]:
            new_I[x:x+n, y+m-1, :] = red
    return new_I

regions_img_test = drawRegions(regions, img_test)
plt.imshow(regions_img_test)

# %% [markdown]
# ### Question 6
# Add a Gaussian noise with standard deviation 5 to the image ``img_test``.
# Apply the quadtree splitting on the noisy image by adjusting the threshold to obtain the same result as in the previous question.
# Which threshold value should be chosen? Does this make sense to you?
#
# Hint: use the Numpy function ``random.randn()`` which generates random values according to a normal distribution (Gaussian distribution of null mean and variance 1). To obtain realizations of a Gaussian distribution of standard deviation $\sigma$, it is sufficient to multiply by $\sigma$ the realizations of a normal distribution.

# %%
from numpy import random

def gaussian_noise(I, sig):
    noise = random.randn(*I.shape)*sig 
    return (I + noise).astype(int)

def show_segmentation(I, *args, ax=None):
    split_tree = split(I, (0,0, *I.shape), predsplit, *args)
    regions = listRegions(split_tree, [])
    regions_img = drawRegions(regions, I)
    if ax:
        ax.set_title(f"Threshold : {args}, nb_region : {len(regions)}")
        ax.imshow(regions_img)
    else:
        plt.imshow(regions_img)
        plt.show()
    return regions_img

noisy_img_test = gaussian_noise(img_test, sig=5)
plt.imshow(noisy_img_test)

# %%
fig, ax = plt.subplots(nrows=4, ncols=3, figsize=(20,20))
ax = ax.flatten()
n = 0
for i in np.arange(1, 3.2, 0.2):
    show_segmentation(noisy_img_test, i*5, ax=ax[n])
    ax[n].set_title(f'thres = {round(i,2)}*sigma')
    n += 1

# %% [markdown]
# **je sais pas ici**

# %% [markdown]
# ## Exercise 2
#
# Experiment the split algorithm on the 4 natural images provided. For each image try to find the threshold that seems to you visually the best. Display the number of regions obtained after splitting.

# %%
def search_thres(I):
    _, ax = plt.subplots(nrows=1, ncols=4, figsize=(20,20))
    ax = ax.flatten()
    print(f"Image std : {np.std(I)}")
    for n,i in enumerate([15, 20, 25, 30]):
        show_segmentation(I, i, ax=ax[n])

# %%
for img in [angio, cam, muscle, prisme, seiche]: # 20, 30, 25, 19, 14
    search_thres(img)
# Out:
# Image std : 33.76748539743484
# Image std : 62.34123968732711
# Image std : 56.66370058179967
# Image std : 25.686917499807638
# Image std : 21.512032237446647

# %% [markdown]
# **Pas mal :o**
#
# **Utiliser $\frac{\sigma}{2}$ semble être un bon niveau**

# %% [markdown]
# ## Exercise 3
# ### Question 1
# Modify the function ``listRegions(L)`` to make it a function ``listRegionsStat(L,I)`` which computes the list of leaves of the quadtree ``L``. Each element of this list will be enriched with three scalar values: the first being the size, the second the mean and the third the variance of pixel values of the block in the image ``I``. This function then returns a list whose elements have the following formal type:
# ```python
# type BlockStat = tuple[int**4,int,float**2]
# ```
#
# The first four values are those of the ``Block`` type, the fifth is the size of the block (in number of pixels) and the last two values are the mean and variance calculated over the region.

# %%
# type BlockStat = tuple[int**4,int,float**2]
def compute_stats(reg, I):
    x,y,n,m = reg
    I_cut = I[x:x+n, y:y+m]
    return len(I_cut.flatten()), I_cut.mean(), I_cut.var()

def listRegionsStat(L,I, blocks_list):
    """ QuadTree*Array -> list[BlockStat] """
    if isinstance(L, tuple): # C'est une feuille 
        size, m, v = compute_stats(L, I)
        blocks_list.append((*L, size, m, v))
        return blocks_list
    else:
        for qt in L:
            listRegionsStat(qt, I, blocks_list)
        return blocks_list
listRegionsStat(L, img_test, [])[0]
# Out:
# (0, 0, 32, 32, 1024, 150.0, 0.0)

# %% [markdown]
# ### Question 2
# In the remainder, the formal type is considered:
# ```python
# type Region = list[BlocStats]
# ```
# A region, as seen during the tutorial work, is therefore a list of blocks. Write the predicate ``predmerge(b,R,*args)`` as seen in tutorial work. This function returns ``True`` if the ``b`` block should merge into the ``R`` region. If a merge happens, then the first item of ``R`` will have its statistics updated to describe the statistics of the region ``R`` merged with `b`.

# %%
def predmerge(b,R,*args):
    """ BlocsStat*Region*... -> bool 
        If merge, R[0] is modified
    """
    _, _, _, _, n1, m1, var1 = b
    x, y, n, m, n2, m2, var2 = R[0]
    new_m = (n1*m1 + n2*m2) / (n1 + n2)
    new_var = (n1*(var1 + m1**2) + n2*(var2 + m2**2)) / (n1 + n2) - new_m**2
    if new_var < args[0]**2 :
        R[0] = (x, y, n, m, n1 + n2, new_m, new_var)
        return True
    else:
        return False

# %% [markdown]
# ### Question 3
# Using `predmerge()` and `neighbors()` functions, given at the beginning of the notebook, write the function ``merge()`` discussed in tutorial work (exercise 7.6).
#
# Recalls on Python lists:
# - Remove an element `a` from a list `L`: `L.remove(a)`
# - Test if `a` belongs to a list `L`: `a in L`
# - Iterate the elements of a list `L`: `for a in L:`
# - Access to an element of a list: as with numpy arrays

# %%
def merge(S,I,pred,*args):
    """ QuadTree*Array*(BlockStat*Region*...->bool) -> list[Region]
        Merge the leaves of S in a list of regions
    """
    K = listRegionsStat(S, I, [])
    L = []
    while len(K) > 0:
        b = K.pop(0)
        reg = [b]
        neighbors_list = neighbors(b,K)
        while len(neighbors_list) > 0:
            bn = neighbors_list.pop(0)
            if pred(bn, reg, *args):
                K.remove(bn)
                reg.append(bn)
                for bj in neighbors(bn, K):
                    if not bj in neighbors_list:
                        neighbors_list.append(bj)
        L.append(reg)
    return L

# %% [markdown]
# ### Question 4
# Test the previous functions using the synthetic image `img_test`. In particular, check that merge() returns a list of 3 elements (i.e. 3 regions).

# %%
QT = split(img_test, (0,0, *img_test.shape), predsplit, 0)
M = merge(QT, img_test, predmerge, 10)
assert len(M) == 3

# %% [markdown]
# ### Question 5
# Write a function ``regions(LR,shape)`` that takes as arguments a list of regions (such as returned by the function ``merge()``) and an image size, and returns an image of the regions. Each region will be colored with the gray level corresponding to the average of the region. The ``shape`` parameter gives the size of the image to be produced.
#
# Test the function on the previous example.

# %%
def regions(LR,shape):
    """ list[Region]*tuple[int,int] -> Array """
    I = np.empty(shape)
    for R in LR:
        for b in R:
            x, y, n, m, _, mu, _ = b
            img[x:x+n, y:y+m] = mu
    return I

def show_segmentation_split_merge(I, predsplit, predmerge, args_split, args_merge, ax=None):
    """
    Image * predicat function split * predicat function merge * tuple[arg split] * tuple[arg merge] * ax facultatif
    """
    split_tree = split(I, (0,0, *I.shape), predsplit, *args_split)
    merged_region = merge(split_tree, I, predmerge, *args_merge)
    regions_img = regions(merged_region, I.shape)
    if ax:
        ax.imshow(regions_img, cmap='gray', vmin=0, vmax=255)
        ax.set_title(f"Args_split : {args_split}, Args_merge : {args_merge}, \n nb_region : {len(merged_region)}")
    else:
        plt.imshow(regions_img,  cmap='gray', vmin=0, vmax=255)
        plt.gca().set_title(f"Args_split : {args_split}, Args_merge : {args_merge}, \n nb_region : {len(merged_region)}")
        plt.show()
    return regions_img

# %%
show_segmentation_split_merge(img_test, predsplit, predmerge, (0,), (10,))
show_segmentation_split_merge(noisy_img_test, predsplit, predmerge, (0,), (10,))
_ = show_segmentation_split_merge(noisy_img_test, predsplit, predmerge, (2*5,), (10,))

# %% [markdown]
# Nice ça fonctionne

# %% [markdown]
# ## Exercise 4: experiments
# ### Question 1
# Test the function ``merge()`` on the images ``angio``, ``cam``, ``muscle``, ``prisme`` and ``seiche``. Try to produce the best segmentations.

# %% [markdown]
# **Pour les paramètres du split, je vais garder les meilleurs trouvés à l'exercice 2**

# %%
def search_thres_merge(I, predsplit, predmerge, args_split, args_merge):
    _, ax = plt.subplots(nrows=2, ncols=3, figsize=(20,20))
    ax = ax.flatten()
    print(f"Image std : {np.std(I)}")
    for n,i in enumerate([10, 15, 20, 25, 30, 35]): # 12, 30, 30, 10, 14
        show_segmentation_split_merge(I, predsplit, predmerge, args_split, (i,), ax=ax[n])

# %%
for img, split_thres in zip([angio, cam, muscle, prisme, seiche], [20, 30, 25, 19, 14]): # 20, 30, 25, 19, 14
    search_thres_merge(img, predsplit, predmerge, (split_thres,), ())
# Out:
# Image std : 33.76748539743484
# Image std : 62.34123968732711
# Image std : 56.66370058179967
# Image std : 25.686917499807638
# Image std : 21.512032237446647

# %% [markdown]
# **Mon nombre de régions ne change pas 🤔**
#
# **Est-ce parce que je fixe la threshold du split ?**

# %%
def search_thres_merge_same(I, predsplit, predmerge, args_split, args_merge):
    _, ax = plt.subplots(nrows=2, ncols=3, figsize=(20,20))
    ax = ax.flatten()
    print(f"Image std : {np.std(I)}")
    for n,i in enumerate([10, 15, 20, 25, 30, 35]): # 12, 30, 30, 10, 14
        show_segmentation_split_merge(I, predsplit, predmerge, (i,), (i,), ax=ax[n])

for img, split_thres in zip([angio, cam, muscle, prisme, seiche], [20, 30, 25, 19, 14]): # 20, 30, 25, 19, 14
    search_thres_merge_same(img, predsplit, predmerge, (), ())
# Out:
# Image std : 33.76748539743484
# Image std : 62.34123968732711
# Image std : 56.66370058179967
# Image std : 25.686917499807638
# Image std : 21.512032237446647

# %% [markdown]
# **Visiblement oui c'était ça 🤔🤔**
#
# **Mais c'est déjà beaucoup plus cohérant comme ça !!**

# %% [markdown]
# **Encore une fois, une theshold proche de $\frac{\sigma}{2}$ semble être un bon niveau**

# %% [markdown]
# ### Question 2
# The result of the merge algorithm highly depends on how you visit the regions. One can then sort the leaves of the quadtree, for example, from the smallest to the largest blocks, or the opposite (use the Python function ``sorted()``).
# The same question arises when calculating the set of neighbors of the merged region. Should they be sorted? If yes, according to which criteria? their size? their proximity?
# Obviously there is no universal answer but it should be adapted to each type of problem.
# Do some tests to see the influence of these sortings on the result of the merger.

# %%
def merge_sort(S, I, pred, sort_type, *args):
    """ QuadTree*Array*(BlockStat*Region*...->bool) -> list[Region]
        Merge the leaves of S in a list of regions starting with the smallest
    """
    K = listRegionsStat(S, I, [])
    if sort_type=="asc":
        K = sorted(K, key=lambda x: x[4])
    elif sort_type=="desc":
        K = sorted(K, key=lambda x: x[4], reverse=True)
    else:
        print("wrong sort_type")
    
    L = []
    while len(K) > 0:
        b = K.pop(0)
        reg = [b]
        neighbors_list = neighbors(b,K)
        for bn in neighbors_list:
            if pred(bn, reg, *args):
                K.remove(bn)
                reg.append(bn)
                for bj in neighbors(bn, K):
                    if not bj in neighbors_list:
                        neighbors_list.append(bj)
        L.append(reg)
    return L

def show_segmentation_split_merge_sort(I, predsplit, predmerge, args_split, args_merge, sort_type, ax=None):
    """
    Image * predicat function split * predicat function merge * tuple[arg split] * tuple[arg merge] * ax facultatif
    """
    split_tree = split(I, (0,0, *I.shape), predsplit, *args_split)
    merged_region = merge_sort(split_tree, I, predmerge, sort_type, *args_merge)
    regions_img = regions(merged_region, I.shape)
    if ax:
        ax.set_title(f"Args_split : {args_split}, Args_merge : {args_merge}, \n nb_region : {len(merged_region)}, {sort_type} sort")
        ax.imshow(regions_img, cmap='gray')
    else:
        plt.imshow(regions_img, cmap='gray')
        plt.show()

    return regions_img

def search_sort_merge(I, predsplit, predmerge, args_split, args_merge):
    _, ax = plt.subplots(nrows=1, ncols=2, figsize=(20,20))
    ax = ax.flatten()
    print(f"Image std : {np.std(I)}")# 12, 30, 30, 10, 14
    show_segmentation_split_merge_sort(I, predsplit, predmerge, args_split, args_merge, "desc", ax=ax[0])
    # ax[0].set_title('Desc Sort')
    show_segmentation_split_merge_sort(I, predsplit, predmerge, args_split, args_merge, "asc", ax=ax[1])
    # ax[1].set_title('Asc Sort')

# %%
for img in zip([angio, cam, muscle, prisme, seiche]):
    threshold = int(np.std(img)/2)
    search_sort_merge(img, predsplit, predmerge, (threshold,), (threshold,))
# Out:
# Image std : 33.76748539743484
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /home/charles/M1-S1-DAC/BIMA/TME/TME7/TME7.ipynb Cell 44 in <cell line: 1>()
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/charles/M1-S1-DAC/BIMA/TME/TME7/TME7.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> for img in zip([angio, cam, muscle, prisme, seiche]):
#       <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/charles/M1-S1-DAC/BIMA/TME/TME7/TME7.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a>     threshold = int(np.std(img)/2)
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/charles/M1-S1-DAC/BIMA/TME/TME7/TME7.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a>     search_sort_merge(img, predsplit, predmerge, (threshold,), (threshold,))
#
# /home/charles/M1-S1-DAC/BIMA/TME/TME7/TME7.ipynb Cell 44 in search_sort_merge(I, predsplit, predmerge, args_split, args_merge)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/charles/M1-S1-DAC/BIMA/TME/TME7/TME7.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=45'>46</a> ax = ax.flatten()
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/charles/M1-S1-DAC/BIMA/TME/TME7/TME7.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=46'>47</a> print(f"Image std : {np.std(I)}")# 12, 30, 30, 10, 14
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/charles/M1-S1-DAC/BIMA/TME/TME7/TME7.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=47'>48</a> show_segmentation_split_merge_sort(I, predsplit, predmerge, args_split, args_merge, "desc", ax=ax[0])
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/charles/M1-S1-DAC/BIMA/TME/TME7/TME7.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=48'>49</a> # ax[0].set_title('Desc Sort')
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/charles/M1-S1-DAC/BIMA/TME/TME7/TME7.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=49'>50</a> show_segmentation_split_merge_sort(I, predsplit, predmerge, args_split, args_merge, "asc", ax=ax[1])
#
# /home/charles/M1-S1-DAC/BIMA/TME/TME7/TME7.ipynb Cell 44 in show_segmentation_split_merge_sort(I, predsplit, predmerge, args_split, args_merge, sort_type, ax)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/charles/M1-S1-DAC/BIMA/TME/TME7/TME7.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=27'>28</a> def show_segmentation_split_merge_sort(I, predsplit, predmerge, args_split, args_merge, sort_type, ax=None):
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/charles/M1-S1-DAC/BIMA/TME/TME7/TME7.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=28'>29</a>     """
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/charles/M1-S1-DAC/BIMA/TME/TME7/TME7.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=29'>30</a>     Image * predicat function split * predicat function merge * tuple[arg split] * tuple[arg merge] * ax facultatif
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/charles/M1-S1-DAC/BIMA/TME/TME7/TME7.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=30'>31</a>     """
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/charles/M1-S1-DAC/BIMA/TME/TME7/TME7.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=31'>32</a>     split_tree = split(I, (0,0, *I.shape), predsplit, *args_split)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/charles/M1-S1-DAC/BIMA/TME/TME7/TME7.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=32'>33</a>     merged_region = merge_sort(split_tree, I, predmerge, sort_type, *args_merge)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/charles/M1-S1-DAC/BIMA/TME/TME7/TME7.ipynb#X52sdnNjb2RlLXJlbW90ZQ%3D%3D?line=33'>34</a>     regions_img = regions(merged_region, I.shape)
#
# AttributeError: 'tuple' object has no attribute 'shape'

# %% [markdown]
# **Sur nos images et avec notre prédicats, l'ordre du merge ne semble pas changer grand chose. Le nombre de régions ne varie que légèrement**
#
# **Essayons un sort sur la variance : à gauche un sort desc sur la size et à droite desc sur la variance**

# %%
def merge_sort_var(S, I, pred, sort_type, *args):
    """ QuadTree*Array*(BlockStat*Region*...->bool) -> list[Region]
        Merge the leaves of S in a list of regions starting with the smallest
    """
    K = listRegionsStat(S, I, [])
    if sort_type=="asc":
        K = sorted(K, key=lambda x: x[-1])
    elif sort_type=="desc":
        K = sorted(K, key=lambda x: x[-1], reverse=True)
    else:
        print("wrong sort_type")
    
    L = []
    while len(K) > 0:
        b = K.pop(0)
        reg = [b]
        neighbors_list = neighbors(b,K)
        for bn in neighbors_list:
            if pred(bn, reg, *args):
                K.remove(bn)
                reg.append(bn)
                for bj in neighbors(bn, K):
                    if not bj in neighbors_list:
                        neighbors_list.append(bj)
        L.append(reg)
    return L

def show_segmentation_split_merge_sort_var(I, predsplit, predmerge, args_split, args_merge, sort_type, ax=None):
    """
    Image * predicat function split * predicat function merge * tuple[arg split] * tuple[arg merge] * ax facultatif
    """
    split_tree = split(I, (0,0, *I.shape), predsplit, *args_split)
    merged_region = merge_sort_var(split_tree, I, predmerge, sort_type, *args_merge)
    regions_img = regions(merged_region, I.shape)
    if ax:
        ax.set_title(f"Args_split : {args_split}, Args_merge : {args_merge}, \n nb_region : {len(merged_region)}, {sort_type} std sort")
        ax.imshow(regions_img, cmap='gray')
    else:
        plt.imshow(regions_img, cmap='gray')
        plt.show()

    return regions_img

def search_sort_merge_var(I, predsplit, predmerge, args_split, args_merge):
    _, ax = plt.subplots(nrows=1, ncols=2, figsize=(20,20))
    ax = ax.flatten()
    print(f"Image std : {np.std(I)}")# 12, 30, 30, 10, 14
    show_segmentation_split_merge_sort(I, predsplit, predmerge, args_split, args_merge, "desc", ax=ax[0])
    show_segmentation_split_merge_sort_var(I, predsplit, predmerge, args_split, args_merge, "desc", ax=ax[1])

for img, split_thres, merge_thres in zip([angio, cam, muscle, prisme, seiche], 
                                        [20, 30, 25, 19, 14],
                                        [12, 30, 30, 10, 14]): 
    search_sort_merge_var(img, predsplit, predmerge, (split_thres,), (merge_thres,))
# Out:
# Image std : 33.76748539743484
# Image std : 62.34123968732711
# Image std : 56.66370058179967
# Image std : 25.686917499807638
# Image std : 21.512032237446647

# %% [markdown]
# **Ca à l'air de fonctionner ! Sur Angio et Prisme, les merges semblent de meilleurs qualités, sur les autres en revanche cela n'a pas trop d'impact visuel**

# %% [markdown]
# ### Question 3 (bonus)
# Imagine and experiment alternative predicates for both the split and the merge steps. It is possible to use edges-based predicates, and also to combine with variance-based predicates.

# %% [markdown]
# **On pourrait combiner notre merge avec une detection de coins et de bordure comme on a vu précédement**

# %% [markdown]
# **On pourrait utiliser la moyenne à la place de la variance également. Ici je vais afficher la moyenne -20, m-30, ...**

# %%
def predmerge_mean(b,R,*args):
    """ BlocsStat*Region*... -> bool 
        If merge, R[0] is modified
    """
    _, _, _, _, n1, m1, var1 = b
    x, y, n, m, n2, m2, var2 = R[0]

    new_m = (n1*m1 + n2*m2)/(n1 + n2)
    new_var = (n1*(var1 + m1**2) + n2*(var2 + m2**2))/(n1 + n2) - new_m**2
    if np.abs(m1-m2) < args[0]**2 :
        R[0] = (x, y, n, m, n1+n2, m1, var1)
        return True
    else:
        return False

def search_thres_merge_mean(I, predsplit, predmerge, args_split, args_merge):
    _, ax = plt.subplots(nrows=2, ncols=3, figsize=(20,20))
    ax = ax.flatten()
    print(f"Image std : {np.std(I)}")
    m = np.mean(I)
    for n,i in enumerate([10, 15, 20, 25, 30, 35]): # 12, 30, 30, 10, 14
        thres = round(m + i)
        show_segmentation_split_merge(I, predsplit, predmerge, args_split, (thres,), ax=ax[n])

for img, split_thres in zip([angio, cam, muscle, prisme, seiche], [20, 30, 25, 19, 14]): # 20, 30, 25, 19, 14
    print("image mean", np.mean(img))
    search_thres_merge_mean(img, predsplit, predmerge_mean, (split_thres,), ())
# Out:
# image mean 58.887451171875
# Image std : 33.76748539743484
# image mean 118.7244873046875
# Image std : 62.34123968732711
# image mean 133.14224243164062
# Image std : 56.66370058179967
# image mean 87.91030883789062
# Image std : 25.686917499807638
# image mean 94.23023986816406
# Image std : 21.512032237446647

# %% [markdown]
# **CCL : **
